# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
RUN_NUMBER = 20

# %%
training_log_filename = f"../outputs/training_runs/run{RUN_NUMBER}/training_log.csv"
print("Loading data from", training_log_filename)
training_log = pd.read_csv(training_log_filename)
# Out:
# Loading data from ../outputs/training_runs/run20/training_log.csv

# %%
plt.scatter(training_log.iteration, training_log.total_reward)
plt.xlabel("Number of iterations")
plt.ylabel("Total Run Reward")
# Out:
# Text(0, 0.5, 'Total Run Reward')
